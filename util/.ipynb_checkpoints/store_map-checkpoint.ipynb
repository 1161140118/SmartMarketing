# %%
# !pip install folium
import folium

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
store = pd.read_csv("../data/shop.csv")

# %%
store
# Out:
#                        store                           labels  \
# 0                远大购物中心(群力店)                     购物服务;商场;购物中心
# 1                    王府井购物中心                     购物服务;商场;购物中心
# 2                卓展购物中心(安红街)                     购物服务;商场;购物中心
# 3                     哈尔滨新一百                     购物服务;商场;购物中心
# 4                 麦凯乐(哈尔滨总店)                     购物服务;商场;普通商场
# 5                   金安国际购物广场                     购物服务;商场;购物中心
# 6                凯德广场(埃德蒙顿路)                     购物服务;商场;购物中心
# 7                     大发生活广场                       购物服务;商场;商场
# 8                 优衣库(中央大街店)               购物服务;服装鞋帽皮具店;品牌服装店
# 9                 万象城(西三道街店)                     购物服务;商场;购物中心
# 10                   透笼国际商品城                     购物服务;商场;购物中心
# 11                  哈尔滨海宁皮革城             购物服务;服装鞋帽皮具店;服装鞋帽皮具店
# 12          松雷商业大厦(道里店)(装修中)                     购物服务;商场;普通商场
# 13                迪卡侬(埃德蒙顿店)                  购物服务;体育用品店;户外用品
# ...
